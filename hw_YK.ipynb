# %%
#Управляющие конструкции и коллекции#

# %%
#Задача_1#

# %%
vs = input("Vvedite slovo: ")
fs = len(vs)
word = fs / 2
if fs % 2 == 0:
    print(vs[int(word)-1:int(word)+1])
elif fs % 2 !=0:
    print(ent_Str[int(word)])
# Out:
# Vvedite slovo: аенрпо
# нр

# %%
#Задача_2#

# %%
a = int(input())
sum = 0
while a != 0:
    sum += a
    a = int(input())
print(sum)
# Out:
# 1
# 2
# 0
# 3

# %%
#Задача_3#

# %%
boys = ['Peter','Alex', 'John', 'Arthur', 'Richard',]
girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']
if len(boys)==len(girls):
    print("Идеальная пара:")
    boys.sort()
    girls.sort()
    humans = zip(boys, girls)
    for bs in humans:
        print(f"{bs[0]} и {bs[1]}")
else:
 
    print("Кто то может остаться без пары")
# Out:
# Идеальная пара:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha

# %%
#Задача_4#

# %%
countries_temperature = [
    ['Thailand', [75.2, 77, 78.8, 73.4, 68, 75.2, 77]],
    ['Germany', [57.2, 55.4, 59, 59, 53.6]],
    ['Russia', [35.6, 37.4, 39.2, 41, 42.8, 39.2, 35.6]],
    ['Poland', [50, 50, 53.6, 57.2, 55.4, 55.4]]
]

for i in countries_temperature:
    print(i[0], '-', round((sum(i[1]) / len(i[1]) - 32) / 1.8, 1), 'C')
