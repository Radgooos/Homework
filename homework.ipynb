# %%
#homework#

# %%
#Osnovy payton#
#zadagha_1#
phrase_1 = 'Доброе_утро'
phrase_2 = 'Добрый_вечер'
if len(phrase_1) > len(phrase_2):
    print('Фраза_1 больше фразы_2')
elif len(phrase_1) < len(phrase_2):
    print('Фраза_2 больше_фразы_1')
elif len(phrase_1) == len(phrase_2):
    print('Фразы_равны')
print('end')
# Out:
# Фраза_2 больше_фразы_1
# end

# %%
#zadagha_2#
year = 4000
if (year % 4 == 0) and (year % 100 != 0) or (year % 400 == 0):
    print(year, '- Високосный_год')
else:
    print(year, '- Обычный_год')    
print('end')
# Out:
# 4000 - Високосный_год
# end

# %%
#zadagha_3#
number = 3
month = 'Май'
if number >= 21 and month == 'Март' or number <= 20 and month == 'Апрель':
    print('Знак_зодиака - Овен')
elif number >= 21 and month == 'Апрель' or number <= 21 and month == 'Май':
    print('Знак_зодиака - Телец')
elif number >= 22 and month == 'Май' or number <= 21 and month == 'Июнь':
    print('Знак_зодиака - Близнецы')
elif number >= 22 and month == 'Июнь' or number <= 22 and month == 'Июль':
    print('Знак_зодиака - Рак')
elif number >= 23 and month == 'Июль' or number <= 23 and month == 'Август':
    print('Знак_зодиака - Лев') 
elif number >= 24 and month == 'Август' or number <= 23 and month == 'Сентябрь':
    print('Знак_зодиака - Дева') 
elif number >= 24 and month == 'Сентябрь' or number <= 23 and month == 'Октябрь':
    print('Знак_зодиака - Весы') 
elif number >= 24 and month == 'Октябрь' or number <= 22 and month == 'Ноябрь':
    print('Знак_зодиака - Скорпион')
elif number >= 23 and month == 'Ноябрь' or number <= 21 and month == 'Декабрь':
    print('Знак_зодиака - Стрелец') 
elif number >= 22 and month == 'Декабрь' or number <= 20 and month == 'Январь':
    print('Знак_зодиака - Козерог')
elif number >= 21 and month == 'Январь' or number <= 18 and month == 'Февраль':
    print('Знак_зодиака - Водолей')
elif number >= 19 and month == 'Февраль' or number <= 20 and month == 'Март':
    print('Знак_зодиака - Рыбы') 
print('end')
# Out:
# Знак_зодиака - Телец
# end

# %%
#zadagha_4#
width = 16
lenght = 16
height = 16
if width < 15 and lenght < 15 and height < 15:
    print('korobka №1')
elif 15 < width < 50 or 15 < lenght < 50 or 15 < height < 50:
    print('korobka 2')
elif lenght > 200:
    print('ypakovka_dly_lyg')
else:
    print('korobka №3')
print('end')
# Out:
# korobka 2
# end
